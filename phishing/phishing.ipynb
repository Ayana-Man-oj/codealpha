# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayana-Man-oj/codealpha/blob/main/phishing/phishing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<title>Phishing Awareness Training</title>

<style>
body {
    font-family: Arial, sans-serif;
    margin: 0;
    background: #f4f6f9;
}

header {
    background: #1e3c72;
    color: white;
    padding: 20px;
    text-align: center;
}

section {
    padding: 25px;
    margin: 20px;
    background: white;
    border-radius: 10px;
    box-shadow: 0 5px 15px rgba(0,0,0,0.1);
}

h2 {
    color: #1e3c72;
}

.highlight {
    background: #ffe6e6;
    padding: 10px;
    border-left: 5px solid red;
}

button {
    padding: 10px 20px;
    background: #1e3c72;
    color: white;
    border: none;
    border-radius: 5px;
    cursor: pointer;
}

button:hover {
    background: #16305c;
}

.result {
    font-weight: bold;
    margin-top: 15px;
}

footer {
    text-align: center;
    padding: 15px;
    background: #1e3c72;
    color: white;
}
</style>
</head>

<body>

<header>
<h1>🛡 Phishing Awareness Training</h1>
<p>Learn to identify and prevent phishing attacks</p>
</header>

<section>
<h2>📌 What is Phishing?</h2>
<p>Phishing is a cyber attack where attackers impersonate trusted organizations to steal sensitive data like passwords, bank details, or personal information.</p>
</section>

<section>
<h2>📧 Recognizing Phishing Emails</h2>
<ul>
<li>Suspicious sender email address</li>
<li>Urgent or threatening language</li>
<li>Spelling and grammar mistakes</li>
<li>Unexpected attachments or links</li>
<li>Requests for passwords or OTP</li>
</ul>

<div class="highlight">
Example: "Your account will be blocked in 24 hours! Click here to verify immediately."
</div>
</section>

<section>
<h2>🌐 Identifying Fake Websites</h2>
<ul>
<li>Misspelled domain (paypa1.com)</li>
<li>No HTTPS lock symbol</li>
<li>Poor design and formatting</li>
<li>Unrealistic offers</li>
</ul>
</section>

<section>
<h2>🧠 Social Engineering Tactics</h2>
<ul>
<li>Creating urgency or fear</li>
<li>Impersonating authority (Bank, Police, IT Admin)</li>
<li>Offering fake rewards</li>
<li>Emotional manipulation</li>
</ul>
</section>

<section>
<h2>✅ Best Practices</h2>
<ul>
<li>Never click suspicious links</li>
<li>Enable Two-Factor Authentication (2FA)</li>
<li>Verify sender identity</li>
<li>Keep software updated</li>
<li>Use strong, unique passwords</li>
</ul>
</section>

<section>
<h2>🧪 Interactive Quiz</h2>

<p>1. What is a common sign of phishing?</p>
<input type="radio" name="q1" value="a"> Professional branding<br>
<input type="radio" name="q1" value="b"> Urgent request demanding action<br>
<input type="radio" name="q1" value="c"> Personalized greeting<br><br>

<p>2. Which website looks suspicious?</p>
<input type="radio" name="q2" value="a"> https://www.paypal.com<br>
<input type="radio" name="q2" value="b"> https://www.paypa1.com<br>
<input type="radio" name="q2" value="c"> https://www.amazon.com<br><br>

<p>3. Should you share OTP with anyone?</p>
<input type="radio" name="q3" value="a"> Yes<br>
<input type="radio" name="q3" value="b"> No<br><br>

<button onclick="checkQuiz()">Submit Quiz</button>
<p class="result" id="result"></p>

</section>

<footer>
<p>Cyber Security Awareness Training Module</p>
</footer>

<script>
function checkQuiz() {
    let score = 0;

    let q1 = document.querySelector('input[name="q1"]:checked');
    let q2 = document.querySelector('input[name="q2"]:checked');
    let q3 = document.querySelector('input[name="q3"]:checked');

    if (q1 && q1.value === "b") score++;
    if (q2 && q2.value === "b") score++;
    if (q3 && q3.value === "b") score++;

    let result = document.getElementById("result");

    if (score === 3) {
        result.innerHTML = "🎉 Excellent! You are phishing aware! Score: " + score + "/3";
        result.style.color = "green";
    } else if (score === 2) {
        result.innerHTML = "👍 Good! Review once more. Score: " + score + "/3";
        result.style.color = "orange";
    } else {
        result.innerHTML = "⚠️ You need more awareness training. Score: " + score + "/3";
        result.style.color = "red";
    }
}
</script>

</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Phishing Awareness Training</title>
#
# <style>
# body {
#     font-family: Arial, sans-serif;
#     margin: 0;
#     background: #f4f6f9;
# }
#
# header {
#     background: #1e3c72;
#     color: white;
#     padding: 20px;
#     text-align: center;
# }
#
# section {
#     padding: 25px;
#     margin: 20px;
#     background: white;
#     border-radius: 10px;
#     box-shadow: 0 5px 15px rgba(0,0,0,0.1);
# }
#
# h2 {
#     color: #1e3c72;
# }
#
# .highlight {
#     background: #ffe6e6;
#     padding: 10px;
#     border-left: 5px solid red;
# }
#
# button {
#     padding: 10px 20px;
#     background: #1e3c72;
#     color: white;
#     border: none;
#     border-radius: 5px;
#     cursor: pointer;
# }
#
# button:hover {
#     background: #16305c;
# }
#
# .result {
#     font-weight: bold;
#     margin-top: 15px;
# }
#
# footer {
#     text-align: center;
#     padding: 15px;
#     background: #1e3c72;
# ...
